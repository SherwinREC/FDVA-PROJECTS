# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv("student_data.csv")
print(df)
# Out:
#          Name   Age  Gender Department  Marks
# 0      Harish  20.0    Male       AIML   85.0
# 1   Keerthana  21.0  Female       AIDS   90.0
# 2       Kavin   NaN    Male       AIML   78.0
# 3      Harini  22.0  Female       AIDS    NaN
# 4   Keerthana  21.0  Female       AIDS   90.0
# 5       Surya  20.0    Male       AIML   88.0
# 6     Yazhini  23.0  female       AIDS   75.0
# 7      Pranav  22.0    Male       AIML   92.0
# 8      Nithya  21.0  Female       AIDS   81.0
# 9      Naveen  20.0    Male       AIML   86.0
# 10    Sanjana  22.0  Female       AIDS   89.0
# 11     Dinesh  21.0    Male       AIML   80.0

# %%
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        12 non-null     object
#  1   Age         11 non-null     float64
#  2   Gender      12 non-null     object
#  3   Department  12 non-null     object
#  4   Marks       11 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 612.0+ bytes
#              Name        Age Gender Department      Marks
# count          12  11.000000     12         12  11.000000
# unique         11        NaN      3          2        NaN
# top     Keerthana        NaN   Male       AIML        NaN
# freq            2        NaN      6          6        NaN
# mean          NaN  21.181818    NaN        NaN  84.909091
# std           NaN   0.981650    NaN        NaN   5.611676
# min           NaN  20.000000    NaN        NaN  75.000000
# 25%           NaN  20.500000    NaN        NaN  80.500000
# 50%           NaN  21.000000    NaN        NaN  86.000000
# 75%           NaN  22.000000    NaN        NaN  89.500000
# max           NaN  23.000000    NaN        NaN  92.000000

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           1
# Gender        0
# Department    0
# Marks         1
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
print(df)
# Out:
#          Name   Age  Gender Department      Marks
# 0      Harish  20.0    Male       AIML  85.000000
# 1   Keerthana  21.0  Female       AIDS  90.000000
# 2       Kavin  21.0    Male       AIML  78.000000
# 3      Harini  22.0  Female       AIDS  84.909091
# 4   Keerthana  21.0  Female       AIDS  90.000000
# 5       Surya  20.0    Male       AIML  88.000000
# 6     Yazhini  23.0  female       AIDS  75.000000
# 7      Pranav  22.0    Male       AIML  92.000000
# 8      Nithya  21.0  Female       AIDS  81.000000
# 9      Naveen  20.0    Male       AIML  86.000000
# 10    Sanjana  22.0  Female       AIDS  89.000000
# 11     Dinesh  21.0    Male       AIML  80.000000

# %%
dupli = df.duplicated()
print(dupli)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
df.drop_duplicates()
print(df)
# Out:
#          Name   Age  Gender Department      Marks
# 0      Harish  20.0    Male       AIML  85.000000
# 1   Keerthana  21.0  Female       AIDS  90.000000
# 2       Kavin  21.0    Male       AIML  78.000000
# 3      Harini  22.0  Female       AIDS  84.909091
# 4   Keerthana  21.0  Female       AIDS  90.000000
# 5       Surya  20.0    Male       AIML  88.000000
# 6     Yazhini  23.0  female       AIDS  75.000000
# 7      Pranav  22.0    Male       AIML  92.000000
# 8      Nithya  21.0  Female       AIDS  81.000000
# 9      Naveen  20.0    Male       AIML  86.000000
# 10    Sanjana  22.0  Female       AIDS  89.000000
# 11     Dinesh  21.0    Male       AIML  80.000000

# %%
df["Gender"] = df["Gender"].str.strip().str.capitalize()
df["Department"] = df["Department"].str.strip().str.upper()
print(df)
# Out:
#          Name   Age  Gender Department      Marks
# 0      Harish  20.0    Male       AIML  85.000000
# 1   Keerthana  21.0  Female       AIDS  90.000000
# 2       Kavin  21.0    Male       AIML  78.000000
# 3      Harini  22.0  Female       AIDS  84.909091
# 4   Keerthana  21.0  Female       AIDS  90.000000
# 5       Surya  20.0    Male       AIML  88.000000
# 6     Yazhini  23.0  Female       AIDS  75.000000
# 7      Pranav  22.0    Male       AIML  92.000000
# 8      Nithya  21.0  Female       AIDS  81.000000
# 9      Naveen  20.0    Male       AIML  86.000000
# 10    Sanjana  22.0  Female       AIDS  89.000000
# 11     Dinesh  21.0    Male       AIML  80.000000

# %%
df["Age"] = df["Age"].astype(int)
df["Marks"] = df["Marks"].round(1)
print(df.dtypes)
# Out:
# Name           object
# Age             int32
# Gender         object
# Department     object
# Marks         float64
# dtype: object

# %%
minmax = MinMaxScaler()

df[["Marks"]] = minmax.fit_transform(df[["Marks"]])
print(df[Marks])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 minmax = MinMaxScaler()
#       3 df[["Marks"]] = minmax.fit_transform(df[["Marks"]])
# ----> 4 print(df[Marks])
#
# NameError: name 'Marks' is not defined

# %%
standard = StandardScaler()
df[["Age"]] = standard.fit_transform(df[["Age"]])
print(df)
# Out:
#          Name       Age  Gender Department     Marks
# 0      Harish -1.299867    Male       AIML  0.588235
# 1   Keerthana -0.185695  Female       AIDS  0.882353
# 2       Kavin -0.185695    Male       AIML  0.176471
# 3      Harini  0.928477  Female       AIDS  0.582941
# 4   Keerthana -0.185695  Female       AIDS  0.882353
# 5       Surya -1.299867    Male       AIML  0.764706
# 6     Yazhini  2.042649  Female       AIDS  0.000000
# 7      Pranav  0.928477    Male       AIML  1.000000
# 8      Nithya -0.185695  Female       AIDS  0.352941
# 9      Naveen -1.299867    Male       AIML  0.647059
# 10    Sanjana  0.928477  Female       AIDS  0.823529
# 11     Dinesh -0.185695    Male       AIML  0.294118

# %%
df.describe()
df.info()
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        12 non-null     object
#  1   Age         12 non-null     float64
#  2   Gender      12 non-null     object
#  3   Department  12 non-null     object
#  4   Marks       12 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 612.0+ bytes
#          Name       Age  Gender Department     Marks
# 0      Harish -1.299867    Male       AIML  0.588235
# 1   Keerthana -0.185695  Female       AIDS  0.882353
# 2       Kavin -0.185695    Male       AIML  0.176471
# 3      Harini  0.928477  Female       AIDS  0.582941
# 4   Keerthana -0.185695  Female       AIDS  0.882353
# 5       Surya -1.299867    Male       AIML  0.764706
# 6     Yazhini  2.042649  Female       AIDS  0.000000
# 7      Pranav  0.928477    Male       AIML  1.000000
# 8      Nithya -0.185695  Female       AIDS  0.352941
# 9      Naveen -1.299867    Male       AIML  0.647059
# 10    Sanjana  0.928477  Female       AIDS  0.823529
# 11     Dinesh -0.185695    Male       AIML  0.294118
